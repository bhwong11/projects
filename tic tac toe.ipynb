# %%
#winning combos
move_board_list_x_win1 = ['x','o','o','x','o','o','x','o','o']
move_board_list_x_win2 = ['o','x','o','o','x','o','o','x','o']
move_board_list_x_win3 = ['o','o','x','o','o','x','o','o','x']

move_board_list_x_win4 = ['x','x','x','o','o','o','o','o','o']
move_board_list_x_win5 = ['o','o','o','x','x','x','o','o','o']
move_board_list_x_win6 = ['o','o','o','o','o','o','x','x','x']

move_board_list_x_win7 = ['x','o','o','o','x','o','o','o','x']
move_board_list_x_win8 = ['o','o','x','o','x','o','x','o','o']

move_board_list_o_win1 = ['o', 'x', 'x', 'o', 'x', 'x', 'o', 'x', 'x']
move_board_list_o_win2 = ['x', 'o', 'x', 'x', 'o', 'x', 'x', 'o', 'x']
move_board_list_o_win3 = ['x', 'x', 'o', 'x', 'x', 'o', 'x', 'x', 'o']
move_board_list_o_win4 = ['o', 'o', 'o', 'x', 'x', 'x', 'x', 'x', 'x']
move_board_list_o_win5 = ['x', 'x', 'x', 'o', 'o', 'o', 'x', 'x', 'x']
move_board_list_o_win6 = ['x', 'x', 'x', 'x', 'x', 'x', 'o', 'o', 'o']
move_board_list_o_win7 = ['o', 'x', 'x', 'x', 'o', 'x', 'x', 'x', 'o']
move_board_list_o_win8 = ['x', 'x', 'o', 'x', 'o', 'x', 'o', 'x', 'x']


def display_board(board = ['',"","","","",'','','','']):
    print(board[0] + '|' + board[1] + '|' + board [2])
    print('_____')
    print(board[3] + '|' + board[4] + '|' + board [5])
    print('_____')
    print(board[6] + '|' + board[7] + '|' + board [8])
    
def check_if_won(current_board):
    win_combos = [move_board_list_x_win1,move_board_list_x_win2,move_board_list_x_win3,
              move_board_list_x_win4,move_board_list_x_win5,move_board_list_x_win6,
              move_board_list_x_win7,move_board_list_x_win8,move_board_list_o_win1,
              move_board_list_o_win2,move_board_list_o_win3,move_board_list_o_win4,
              move_board_list_o_win5,move_board_list_o_win6,move_board_list_o_win7,
              move_board_list_o_win8]
    for i in win_combos:
        if current_board == i:
            game_won = True
        else:
            game_won = False
    return game_won


x = input("start game?")
move_count = 0
move_board_list = ['',"","","","",'','','','']
while x == 'yes':
    if move_count%2 == 0:
        X_move = int(input("x turn. choose position "))
        if move_board_list[X_move-1] != "":
            print('that space is taken')
        else:
            move_board_list[X_move-1] = 'x'
            print(move_board_list)
            display_board(move_board_list)
            win_check_varible = check_if_won(move_board_list)
            move_count += 1
    else:
        O_move = int(input("o turn. choose position "))
        if move_board_list[O_move-1] != "":
            print('that space is taken')
        else:
            move_board_list[O_move-1] = 'o'
            print(move_board_list)
            display_board(move_board_list)
            win_check_varible = check_if_won(move_board_list)
            move_count += 1
            
    if move_count >= 9 or win_check_varible == True:
        continue_playing = input("continue?: ")
        move_board_list = ['',"","","","",'','','','']
        if continue_playing == "no":
            x = 'no'
        else:
            print("new_game")
            move_count = 0
    
    

#win conidition for dianogals maybe a for loop for columns of 3?
#make a function for if a space is taken
#make a function for stoping if win
    #if move_board_list for every step 3 ==x or 4 == x then win
#make function for inputting number positions
#make display board
#make a function that can display board numbers
# make a win condition if the xs and os are in the right position
