# %%
def display_board(board = [' '," "," "," "," ",' ',' ',' ',' ']):
    print(board[0] + '|' + board[1] + '|' + board [2])
    print('_____')
    print(board[3] + '|' + board[4] + '|' + board [5])
    print('_____')
    print(board[6] + '|' + board[7] + '|' + board [8])
    
def check_if_x_won(current_board):
    if current_board[0] == 'x' and current_board[3] == 'x' and current_board[6] == 'x':
        x_win = True
    elif current_board[1] == 'x' and current_board[4] == 'x' and current_board[7] == 'x':
        x_win = True
    elif current_board[2] == 'x' and current_board[5] == 'x'and current_board[8] == 'x':
        x_win = True
    elif current_board[0] == 'x' and current_board[4] == 'x'and current_board[8] == 'x':
        x_win = True
    elif current_board[2] == 'x' and current_board[4] == 'x' and current_board[6] == 'x':
        x_win = True
    elif current_board[0] == 'x' and current_board[1] == 'x' and current_board[2] == 'x':
        x_win = True
    elif current_board[3] == 'x' and current_board[4] == 'x' and current_board[5] == 'x':
        x_win = True
    elif current_board[6] == 'x' and current_board[7] == 'x' and current_board[8] == 'x':
        x_win = True
    else:
        x_win = False
    return x_win
def check_if_o_won(current_board):
    if current_board[0] == 'o' and current_board[3] == 'o' and current_board[6] == 'o':
        o_win = True
    elif current_board[1] == 'o' and current_board[4] == 'o' and current_board[7] == 'o':
        o_win = True
    elif current_board[2] == 'o' and current_board[5] == 'o' and current_board[8] == 'o':
        o_win = True
    elif current_board[0] == 'o' and current_board[4] == 'o' and current_board[8] == 'o':
        o_win = True
    elif current_board[2] == 'o' and current_board[4] == 'o' and current_board[6] == 'o':
        o_win = True
    elif current_board[0] == 'o' and current_board[1] == 'o' and current_board[2] == 'o':
        o_win = True
    elif current_board[3] == 'o' and current_board[4] == 'o' and current_board[5] == 'o':
        o_win = True
    elif current_board[6] == 'o' and current_board[7] == 'o' and current_board[8] == 'o':
        o_win = True
    else:
        o_win = False
    return o_win
#while loop to play game
x = input("start game?")
move_count = 0
move_board_list = [' '," "," "," "," ",' ',' ',' ',' ']
while x == 'yes':
    if move_count%2 == 0:
        X_move = int(input("x turn. choose position "))
        if move_board_list[X_move-1] != " ":
            print('that space is taken')
        else:
            move_board_list[X_move-1] = 'x'
            print(move_board_list)
            display_board(move_board_list)
            move_count += 1
    else:
        O_move = int(input("o turn. choose position "))
        if move_board_list[O_move-1] != " ":
            print('that space is taken')
        else:
            move_board_list[O_move-1] = 'o'
            print(move_board_list)
            display_board(move_board_list)
            move_count += 1
#check if game is over         
    if move_count >= 9:
        continue_playing = input("continue?: ")
        move_board_list = [' '," "," "," "," ",' ',' ',' ',' ']
        if continue_playing == "no":
            x = 'no'
        else:
            print("new_game")
            move_count = 0
    elif check_if_o_won(move_board_list) == True:
        print('O WINS!')
        continue_playing = input("play again?: ")
        move_board_list = [' '," "," "," "," ",' ',' ',' ',' ']
        if continue_playing == "no":
            x = 'no'
        else:
            print("new game")
            move_count = 0
    elif check_if_x_won(move_board_list) == True:
        print('X WINS!')
        continue_playing = input("continue?: ")
        move_board_list = [' '," "," "," "," ",' ',' ',' ',' ']
        if continue_playing == "no":
            x = 'no'
        else:
            print("new game")
            move_count = 0
